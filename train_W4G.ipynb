# %%
import warnings
warnings.filterwarnings('ignore')

import os
import torch
from torch import nn

from hparams.hparams_W4G import create_hparams
from model import Model
from datasets import LJDataset, TextMelCollate
from utils import sizeof_fmt, Logger

# %%
# !nvidia-smi
os.environ["CUDA_VISIBLE_DEVICES"]="1"
# Out:
# Wed Mar 31 19:27:11 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 208...  Off  | 00000000:2E:00.0 Off |                  N/A |
# |100%   88C    P2   175W / 250W |  10786MiB / 11016MiB |     98%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 208...  Off  | 00000000:2F:00.0 Off |                  N/A |
# | 66%   70C    P0    57W / 250W |      0MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A     14026      C   ...onda3/envs/vae/bin/python    10783MiB |
# +-----------------------------------------------------------------------------+

# %%
from parallel_wavegan.utils import download_pretrained_model
from parallel_wavegan.utils import load_model

device='cuda'
vocoder_tag = "ljspeech_parallel_wavegan.v3"

# NOTE: Sometimes download is failed due to "Permission denied". That is 
#   the limitation of google drive. Please retry after serveral hours.
vocoder = load_model(download_pretrained_model(vocoder_tag)).to(device).eval()
vocoder.remove_weight_norm()
print('done')

from parallel_wavegan.utils import read_hdf5

stats_filename = "/home/rubato/.cache/parallel_wavegan/ljspeech_parallel_wavegan.v3/stats.h5"
mean = read_hdf5(stats_filename, 'mean')
scale = read_hdf5(stats_filename, 'scale')
print('done')
# Out:
# done
# done

# %%
save_dir = '/data/save/model_W4G'
logger = Logger(save_dir=save_dir, new=False)
print('done')
# Out:
# done

# %%
# !ls $save_dir
# Out:
# data.json     save_1055245  save_1155000  save_410000  save_815000  save_915000
# save_100000   save_1060000  save_1160000  save_415000  save_820000  save_920000
# save_1000000  save_1065000  save_1165000  save_420000  save_825000  save_925000
# save_1005000  save_1070000  save_1170000  save_421237  save_830000  save_930000
# save_1010000  save_1075000  save_1175000  save_590000  save_835000  save_935000
# save_101436   save_1080000  save_1180000  save_590104  save_837960  save_940000
# save_1014611  save_1085000  save_1185000  save_595000  save_840000  save_945000
# save_1015000  save_1090000  save_1190000  save_600000  save_845000  save_950000
# save_1016689  save_1095000  save_1195000  save_603294  save_850000  save_955000
# save_101938   save_1100000  save_1200000  save_605000  save_855000  save_960000
# save_1020000  save_1105000  save_1205000  save_610000  save_860000  save_965000
# save_102141   save_1110000  save_1210000  save_613078  save_865000  save_970000
# save_1025000  save_1115000  save_1215000  save_615000  save_870000  save_975000
# save_102658   save_1120000  save_1220000  save_618530  save_875000  save_980000
# save_1027006  save_1124029  save_1225000  save_620000  save_880000  save_985000
# save_1030000  save_1125000  save_1230000  save_623935  save_885000  save_990000
# save_1035000  save_1130000  save_1235000  save_750000  save_890000  save_995000
# save_1040000  save_1135000  save_1240000  save_801510  save_895000
# save_1045000  save_1140000  save_1243233  save_805000  save_900000
# save_1050000  save_1145000  save_400000   save_806886  save_905000
# save_1055000  save_1150000  save_405000   save_810000  save_910000

# %%
stt_hparams, tts_hparams = create_hparams()
model = Model(stt_hparams, tts_hparams)
model = model.cuda()
optimizer = torch.optim.Adam(model.parameters(), lr=tts_hparams.lr, weight_decay=tts_hparams.weight_decay)

step = 1243233

size = sizeof_fmt(4 * sum(p.numel() for p in model.parameters()))
print(f"Model size {size}")

size = sizeof_fmt(4 * sum(p.numel() for p in model.tts.parameters()))
print(f"TTS size {size}")

size = sizeof_fmt(4 * sum(p.numel() for p in model.tts.mel_encoder.parameters()))
print(f"MelEncoder size {size}")

size = sizeof_fmt(4 * sum(p.numel() for p in model.tts.mel_decoder.parameters()))
print(f"MelDecoder size {size}")

if True:
    model, optimizer, step = logger.load(step, model, optimizer)
print(step)

print('done')
# Out:
# Model size 124.1MiB
# TTS size 36.5MiB
# MelEncoder size 11.6MiB
# MelDecoder size 22.9MiB
# loaded : 1243233
# 1243233
# done

# %%
trainset = LJDataset(tts_hparams, split='train')
collate_fn = TextMelCollate(tts_hparams)
train_loader = torch.utils.data.DataLoader(trainset, num_workers=8, #tts_hparams.num_workers, 
                          shuffle=True, sampler=None, batch_size=tts_hparams.batch_size, pin_memory=False,
                          drop_last=True, collate_fn=collate_fn)
print(train_loader)

validset = LJDataset(tts_hparams, split='valid')
valid_loader = torch.utils.data.DataLoader(validset, num_workers=tts_hparams.num_workers, 
                          shuffle=True, sampler=None, batch_size=tts_hparams.batch_size, pin_memory=False,
                          drop_last=True, collate_fn=collate_fn)
print(valid_loader)

testset = LJDataset(tts_hparams, split='test')
test_loader = torch.utils.data.DataLoader(testset, num_workers=1, 
                          shuffle=False, sampler=None, batch_size=1, pin_memory=False,
                          drop_last=True, collate_fn=collate_fn)
print(test_loader)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x7f461f49e4f0>
# <torch.utils.data.dataloader.DataLoader object at 0x7f4611a3ac10>
# <torch.utils.data.dataloader.DataLoader object at 0x7f45a0031c70>

# %%
def to_cuda(batch):
    batch['text'] = batch['text'].cuda()
    batch['text_lengths'] = batch['text_lengths'].cuda()
    batch['mels'] = batch['mels'].cuda()
    batch['mel_lengths'] = batch['mel_lengths'].cuda()
    
    return batch

# %%
from IPython import display
import matplotlib.pyplot as plt
import librosa.display
import numpy as np
import time

model.train()

while(True):
    
    for batch in train_loader:
        batch = to_cuda(batch)
        
        model.train()
        model.increase_step()
        model.zero_grad()

        stt_outputs, tts_outputs = model(batch)
        loss = tts_outputs['loss'] + stt_outputs['loss']
        loss.backward()
        
        grad_norm = nn.utils.clip_grad_norm_(model.parameters(), 1)
        print(grad_norm.mean())
        if torch.isnan(grad_norm.mean()):
            continue
        
        optimizer.step()
        
        if step % 5000 == 0:
            logger.save(step, model, optimizer)
        
        if step % 1 == 0:
            print('step :', step, 
                  'stt :', '%0.4f' % stt_outputs['loss'].item(),
                  'tts :', '%0.4f' % tts_outputs['loss'].item(),
                  'recon :', '%0.4f' % tts_outputs['recon_loss'].item(),
                  'kl :', '%0.4f' % tts_outputs['kl_loss'].item(),
                  'beta :', '%0.4f' % model.beta)
                  
            
        if step % 100 == 0:
            logger.log(step, 'stt_loss', stt_outputs['loss'].item())
            logger.log(step, 'tts_loss', tts_outputs['loss'].item())    
            logger.log(step, 'recon_loss', tts_outputs['recon_loss'].item())    
            logger.log(step, 'kl_loss', tts_outputs['kl_loss'].item())    
            logger.log(step, 'beta', model.beta)    
            
        if step % 100 == 0:
            display.clear_output()
            
            index = 0
            model.eval()
            
            with torch.no_grad():
                times = []
                for _ in range(10):
                    t0 = time.time()
                    samples, _ = model.inference(batch['text'], batch['mels'].size(2), stt_outputs["alignments"], temperature=1.0)
                    t1 = time.time()
                    times.append(t1 - t0)
                times = np.array(times)
                print('elapsed time :', np.mean(times))

            try:
                _tts_alignments = tts_outputs["alignments"].data.cpu().numpy()
                batch_size = _tts_alignments.shape[0]
                plt.figure(figsize=[18, 3])
                for i in range(3):
                    plt.subplot(1, 3, i+1)
                    plt.imshow(_tts_alignments[i].T, aspect='auto', origin='lower', interpolation='none')
                plt.show()

                _stt_alignments = stt_outputs["alignments"].data.cpu().numpy()
                batch_size = _stt_alignments.shape[0]
                plt.figure(figsize=[18, 3])
                for i in range(3):
                    plt.subplot(1, 3, i+1)
                    plt.imshow(_stt_alignments[i].T, aspect='auto', origin='lower', interpolation='none')
                plt.show()

                plt.figure(figsize=[18, 3])
                _x = batch['mels'].data.cpu().numpy()
                librosa.display.specshow(_x[index])
                plt.colorbar()

                for i in range(_stt_alignments.shape[1]):
                    plt.plot(_stt_alignments[index, i] * 100)

                plt.show()

                plt.figure(figsize=[18, 3])
                _y = tts_outputs['pred'].data.cpu().numpy()
                librosa.display.specshow(_y[index])
                plt.colorbar()
                plt.show()

                plt.figure(figsize=[18, 3])
                _s = samples.data.cpu().numpy()
                librosa.display.specshow(_s[index, :, :_y.shape[2]])
                plt.colorbar()
                plt.show()
            except:
                pass
                      
        step += 1
# Out:
# elapsed time : 0.02549288272857666
# tensor(-18.4207, device='cuda:0')
# tensor(0.3724, device='cuda:0')
# step : 1380201 stt : 0.0005 tts : 0.2376 recon : 0.0267 kl : 0.0091 beta : 1.0000
# tensor(-3.1432, device='cuda:0')
# tensor(0.3768, device='cuda:0')
# step : 1380202 stt : 0.0016 tts : 0.2356 recon : 0.0251 kl : 0.0086 beta : 1.0000
# tensor(0.5703, device='cuda:0')
# tensor(0.4389, device='cuda:0')
# step : 1380203 stt : 0.0013 tts : 0.2652 recon : 0.0275 kl : 0.0093 beta : 1.0000
# tensor(0.1211, device='cuda:0')
# tensor(0.4304, device='cuda:0')
# step : 1380204 stt : 0.0012 tts : 0.2481 recon : 0.0234 kl : 0.0081 beta : 1.0000
# tensor(-2.5924, device='cuda:0')
# tensor(0.3943, device='cuda:0')
# step : 1380205 stt : 0.0010 tts : 0.2580 recon : 0.0255 kl : 0.0087 beta : 1.0000
# tensor(-3.4626, device='cuda:0')
# tensor(0.5114, device='cuda:0')
# step : 1380206 stt : 0.0028 tts : 0.2562 recon : 0.0253 kl : 0.0088 beta : 1.0000
# tensor(-18.4207, device='cuda:0')
# tensor(0.3785, device='cuda:0')
# step : 1380207 stt : 0.0006 tts : 0.2427 recon : 0.0256 kl : 0.0085 beta : 1.0000
# tensor(0.4287, device='cuda:0')
# tensor(0.4612, device='cuda:0')
# step : 1380208 stt : 0.0012 tts : 0.2537 recon : 0.0224 kl : 0.0078 beta : 1.0000
# tensor(0.4043, device='cuda:0')
# tensor(0.4024, device='cuda:0')
# step : 1380209 stt : 0.0002 tts : 0.2433 recon : 0.0233 kl : 0.0080 beta : 1.0000
# tensor(-18.4207, device='cuda:0')
# tensor(0.3949, device='cuda:0')
# step : 1380210 stt : 0.0005 tts : 0.2606 recon : 0.0243 kl : 0.0081 beta : 1.0000
# tensor(0.3547, device='cuda:0')
# tensor(0.3753, device='cuda:0')
# step : 1380211 stt : 0.0021 tts : 0.2276 recon : 0.0237 kl : 0.0081 beta : 1.0000
# tensor(-18.4207, device='cuda:0')
# tensor(0.4461, device='cuda:0')
# step : 1380212 stt : 0.0016 tts : 0.2813 recon : 0.0261 kl : 0.0088 beta : 1.0000
# tensor(-1.9682, device='cuda:0')
# tensor(0.6068, device='cuda:0')
# step : 1380213 stt : 0.0019 tts : 0.2898 recon : 0.0252 kl : 0.0085 beta : 1.0000
# tensor(-0.5593, device='cuda:0')
# tensor(0.3259, device='cuda:0')
# step : 1380214 stt : 0.0019 tts : 0.2428 recon : 0.0241 kl : 0.0082 beta : 1.0000
# tensor(-3.0385, device='cuda:0')
# tensor(0.5381, device='cuda:0')
# step : 1380215 stt : 0.0014 tts : 0.2769 recon : 0.0282 kl : 0.0091 beta : 1.0000
# tensor(-1.7608, device='cuda:0')
# tensor(0.4068, device='cuda:0')
# step : 1380216 stt : 0.0008 tts : 0.2645 recon : 0.0243 kl : 0.0084 beta : 1.0000
# tensor(-2.8335, device='cuda:0')
# tensor(0.6341, device='cuda:0')
# step : 1380217 stt : 0.0005 tts : 0.2493 recon : 0.0236 kl : 0.0082 beta : 1.0000
# tensor(-18.4207, device='cuda:0')
# tensor(0.4874, device='cuda:0')
# step : 1380218 stt : 0.0016 tts : 0.2534 recon : 0.0252 kl : 0.0087 beta : 1.0000
# tensor(-18.4207, device='cuda:0')
# tensor(0.5111, device='cuda:0')
# step : 1380219 stt : 0.0010 tts : 0.2730 recon : 0.0238 kl : 0.0083 beta : 1.0000
# tensor(-18.4207, device='cuda:0')
# tensor(0.6816, device='cuda:0')
# step : 1380220 stt : 0.0007 tts : 0.2936 recon : 0.0272 kl : 0.0090 beta : 1.0000
# tensor(-0.9203, device='cuda:0')
# tensor(0.3022, device='cuda:0')
# step : 1380221 stt : 0.0018 tts : 0.2256 recon : 0.0269 kl : 0.0089 beta : 1.0000
# tensor(-0.1529, device='cuda:0')
# tensor(0.6124, device='cuda:0')
# step : 1380222 stt : 0.0021 tts : 0.2857 recon : 0.0252 kl : 0.0086 beta : 1.0000
# tensor(-18.4207, device='cuda:0')
# tensor(0.4089, device='cuda:0')
# step : 1380223 stt : 0.0011 tts : 0.2328 recon : 0.0279 kl : 0.0092 beta : 1.0000
# tensor(-3.3777, device='cuda:0')
# tensor(0.6486, device='cuda:0')
# step : 1380224 stt : 0.0011 tts : 0.2809 recon : 0.0260 kl : 0.0087 beta : 1.0000
# tensor(-4.5861, device='cuda:0')
# tensor(0.2979, device='cuda:0')
# step : 1380225 stt : 0.0007 tts : 0.2519 recon : 0.0257 kl : 0.0086 beta : 1.0000
# tensor(-18.4207, device='cuda:0')
# tensor(0.7315, device='cuda:0')
# step : 1380226 stt : 0.0005 tts : 0.2942 recon : 0.0242 kl : 0.0082 beta : 1.0000
# tensor(0.5883, device='cuda:0')
# tensor(0.4085, device='cuda:0')
# step : 1380227 stt : 0.0008 tts : 0.2767 recon : 0.0254 kl : 0.0085 beta : 1.0000
# tensor(0.5633, device='cuda:0')
# tensor(0.4683, device='cuda:0')
# step : 1380228 stt : 0.0010 tts : 0.2424 recon : 0.0257 kl : 0.0087 beta : 1.0000
# tensor(-3.2428, device='cuda:0')
# tensor(0.5726, device='cuda:0')
# step : 1380229 stt : 0.0016 tts : 0.2847 recon : 0.0252 kl : 0.0086 beta : 1.0000
# tensor(-3.7788, device='cuda:0')
# tensor(0.4357, device='cuda:0')
# step : 1380230 stt : 0.0006 tts : 0.2540 recon : 0.0261 kl : 0.0088 beta : 1.0000
# tensor(-2.4234, device='cuda:0')
# tensor(0.4086, device='cuda:0')
# step : 1380231 stt : 0.0014 tts : 0.2537 recon : 0.0233 kl : 0.0080 beta : 1.0000
# tensor(-18.4207, device='cuda:0')
# tensor(0.5428, device='cuda:0')
# step : 1380232 stt : 0.0012 tts : 0.2780 recon : 0.0258 kl : 0.0087 beta : 1.0000
# tensor(-1.3901, device='cuda:0')
# tensor(0.4443, device='cuda:0')
# step : 1380233 stt : 0.0025 tts : 0.2826 recon : 0.0251 kl : 0.0085 beta : 1.0000
# tensor(-18.4207, device='cuda:0')
# tensor(0.4590, device='cuda:0')
# step : 1380234 stt : 0.0010 tts : 0.2297 recon : 0.0250 kl : 0.0085 beta : 1.0000
# tensor(-18.4207, device='cuda:0')
# tensor(0.4082, device='cuda:0')
# step : 1380235 stt : 0.0006 tts : 0.2295 recon : 0.0252 kl : 0.0084 beta : 1.0000
# tensor(-3.2292, device='cuda:0')
# tensor(0.2368, device='cuda:0')
# step : 1380236 stt : 0.0005 tts : 0.2032 recon : 0.0250 kl : 0.0083 beta : 1.0000
# tensor(-1.5233, device='cuda:0')
# tensor(0.4759, device='cuda:0')
# step : 1380237 stt : 0.0016 tts : 0.2573 recon : 0.0251 kl : 0.0085 beta : 1.0000
# tensor(-18.4207, device='cuda:0')
# tensor(0.3512, device='cuda:0')
# step : 1380238 stt : 0.0011 tts : 0.2291 recon : 0.0267 kl : 0.0090 beta : 1.0000
# tensor(-18.4207, device='cuda:0')
# tensor(0.4747, device='cuda:0')
# step : 1380239 stt : 0.0010 tts : 0.2385 recon : 0.0249 kl : 0.0083 beta : 1.0000
# tensor(-1.5548, device='cuda:0')
# tensor(0.3973, device='cuda:0')
# step : 1380240 stt : 0.0007 tts : 0.2259 recon : 0.0250 kl : 0.0086 beta : 1.0000
# tensor(-18.4207, device='cuda:0')
# tensor(0.5766, device='cuda:0')
# step : 1380241 stt : 0.0005 tts : 0.2604 recon : 0.0213 kl : 0.0074 beta : 1.0000
# tensor(-1.1263, device='cuda:0')
# tensor(0.5423, device='cuda:0')
# step : 1380242 stt : 0.0006 tts : 0.2693 recon : 0.0233 kl : 0.0081 beta : 1.0000
# tensor(-1.5175, device='cuda:0')
# tensor(0.2529, device='cuda:0')
# step : 1380243 stt : 0.0012 tts : 0.2002 recon : 0.0254 kl : 0.0087 beta : 1.0000
# tensor(-18.4207, device='cuda:0')
# tensor(0.3540, device='cuda:0')
# step : 1380244 stt : 0.0003 tts : 0.2321 recon : 0.0253 kl : 0.0085 beta : 1.0000
# tensor(-2.0514, device='cuda:0')
# tensor(0.4491, device='cuda:0')
# step : 1380245 stt : 0.0010 tts : 0.2653 recon : 0.0273 kl : 0.0090 beta : 1.0000
# tensor(-18.4207, device='cuda:0')
# tensor(0.4005, device='cuda:0')
# step : 1380246 stt : 0.0011 tts : 0.2604 recon : 0.0270 kl : 0.0090 beta : 1.0000
# tensor(-2.1152, device='cuda:0')
# tensor(0.4665, device='cuda:0')
# step : 1380247 stt : 0.0007 tts : 0.2612 recon : 0.0259 kl : 0.0089 beta : 1.0000
# tensor(0.4635, device='cuda:0')
# tensor(0.6382, device='cuda:0')
# step : 1380248 stt : 0.0007 tts : 0.3163 recon : 0.0231 kl : 0.0078 beta : 1.0000
# tensor(-1.4196, device='cuda:0')
# tensor(0.3365, device='cuda:0')
# step : 1380249 stt : 0.0013 tts : 0.2360 recon : 0.0260 kl : 0.0087 beta : 1.0000
# tensor(-18.4207, device='cuda:0')
# tensor(0.4413, device='cuda:0')
# step : 1380250 stt : 0.0009 tts : 0.2770 recon : 0.0246 kl : 0.0085 beta : 1.0000
# tensor(0.4234, device='cuda:0')
# tensor(0.3570, device='cuda:0')
# step : 1380251 stt : 0.0008 tts : 0.2579 recon : 0.0241 kl : 0.0083 beta : 1.0000
# tensor(-1.7954, device='cuda:0')
# tensor(0.3038, device='cuda:0')
# step : 1380252 stt : 0.0009 tts : 0.2256 recon : 0.0266 kl : 0.0089 beta : 1.0000
# tensor(-18.4207, device='cuda:0')
# tensor(0.3876, device='cuda:0')
# step : 1380253 stt : 0.0007 tts : 0.2464 recon : 0.0259 kl : 0.0088 beta : 1.0000
# tensor(-18.4207, device='cuda:0')
# tensor(0.5522, device='cuda:0')
# step : 1380254 stt : 0.0011 tts : 0.3001 recon : 0.0262 kl : 0.0089 beta : 1.0000
# tensor(-1.8456, device='cuda:0')

# %%
logger.save(step, model, optimizer)
# Out:
# saved /data/save/model_W4G/save_1243233

# %%
import matplotlib.pyplot as plt
import librosa.display
import numpy as np
import time 

for i, batch in enumerate(test_loader):
    batch = to_cuda(batch)
    if i == 22:
        break
print(batch['strings'][0])

model.eval()
with torch.no_grad():
    index = 0
    times = []
    for _ in range(10):
        t0 = time.time()
        samples, time_dict = model.inference(batch['text'][0:1], None, None, temperature=1.0, clip=1.5)
        t1 = time.time()
        times.append(t1 - t0)
    times = np.array(times)
    print(samples.shape, np.mean(times))
    print(time_dict)
    
    plt.figure(figsize=[18, 3])
    _x = batch['mels'].data.cpu().numpy()
    _s = samples.data.cpu().numpy()
    librosa.display.specshow(_s[index])
    plt.colorbar()
    plt.show()
# Out:
# and was in fact the kind of letter used in the many splendid missals, psalters, etc., produced by printing in the fifteenth century.
# torch.Size([1, 80, 747]) 0.028508996963500975
# {'alignment': 0.0005288124084472656, 'random': 0.00562286376953125, 'last_conv': 0.015088558197021484, 'z_proj': 0.0006203651428222656, 'cond': 0.0003769397735595703, 'up': 0.0002803802490234375, 'encode': 0.005169391632080078, 'pad': 3.647804260253906e-05, 'enc_conv': 0.0007162094116210938, 'enc_lstm': 0.0042264461517333984}

# %%
vocoder.eval()
with torch.no_grad():
    _mel = _s[0].T
    _mel = (_mel - mean) / scale
    mel = torch.from_numpy(_mel).cuda()
    wav = vocoder.inference(mel)
    _wav = wav[:, 0].data.cpu().numpy()
    print(_wav.shape)
    
import IPython.display as ipd
ipd.Audio(_wav, rate=22050)
# Out:
# (191232,)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
